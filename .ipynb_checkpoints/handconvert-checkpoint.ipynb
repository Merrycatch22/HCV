# %%
import re, random

filename=raw_input("filename: ") #takes the file's name

file = open(filename)
delim="Bluff Avenue Game"
hand_list = [delim+e for e in file.read().split(delim) if e] #the list of hands, delimited.
file.close()

#print(hand_list)

split_list=[]
for hand in hand_list:
    split_list.append(hand.splitlines()) #split_list is a list of lists: each hand split into lines.
#print(split_list[0])

prog=re.compile('^The button is in seat')
prog2=re.compile('\D:|shows|wins|mucks')
prog3=re.compile('^Uncalled bet of (\$[\d.\.]+)')
prog4=re.compile('posts the (small|big) blind of')
prog5=re.compile('^(Seat \d: \S+ \(\S+)(\))')
prog6=re.compile('^(\S+) ')

prog7=re.compile('^Seat (\d)') #checks if the seats are top and summary

#prog8=re.compile('Bluff Avenue Game #\d+: (.+), Table \d+ - (\$[\d\.]+/\$[\d\.]+) - (\S+ Limit) (\S+) - (\d+:\d+:\d+) \S+ \S+ - (\d+)/(\d+)/(\d+)')
prog8=re.compile('Bluff Avenue Game #\d+: (.+, Table \d+) - (\$[\d\.]+/\$[\d\.]+) - (\S+ Limit) (\S+) - (\d+:\d+:\d+ \S+) \S+ - (\d+)/(\d+)/(\d+)')

prog9=re.compile('^(\S+): posts') # for double blind post warning


splitCount=0 #for last 4 digit purposes
gametimeStorage=[] #for time duplication checking, now with gamename too
for split in split_list:
    
    straddleFlag=True # for the print of the straddle
    
    splitCount+=1 #to update the splitCount
    
    for line in list(split):
        if prog2.search(line):
            split.remove(line)
    
    button="-1"
    
    for line in list(split):
        if prog.match(line):
            #print(line.find('#'))
            button=line[line.find('#')+1:]
            #print(button)
            split.remove(line)
            break
    
    first_re=prog8.match(split[0]) #what does this do fuck
    gamename=first_re.group(1) #name of the game's table, with table number
    
    #print(gamename)
    
    stake=first_re.group(2)
    gametype=first_re.group(4)+" "+first_re.group(3)
    
    #gametime=first_re.group(5)
    
    temptime=first_re.group(5)
    hour=int(temptime[:temptime.index(':')])
    if temptime[-2:]=="AM":
        
        if hour==12:
            hour=0
    elif temptime[-2:]=="PM":
        if hour!=12:
            hour+=12
    gametime=str(hour)+temptime[temptime.index(':'):-3]
    #print(gametime)
        
    gamedate="20"+first_re.group(8)+"/"+first_re.group(6).zfill(2)+"/"+first_re.group(7).zfill(2)
    gamenumber=gamedate.replace("/","")+gametime.replace(":","").zfill(6)+str(splitCount%1000).zfill(4)
    
    split[0]="PokerStars Hand #"+gamenumber+":  "+gametype+" ("+stake+" USD) - "+gamedate+" "+gametime+" ET"
    #split[0]="PokerStars Hand #"+str(random.randint(1,1000000000000))+":  Omaha Pot Limit ($0.10/$0.20 USD) - 2017/07/19 4:59:02 ET"
    split.insert(1,"Table '"+gamename+"' 9-max Seat #"+button+" is the button")
    
    state=0
    seatStringStorage=[] # for seat number storage
    blindStringStorage=[] # for blind storage
    blindDeletion=[]
    
    gamenametime=gamename+gametime
    #print(gamenametime)
    
    if gamenametime in gametimeStorage:
        print("duplicate gametime at "+gamenametime)
    else:
        gametimeStorage.append(gamenametime)
    
    for i,line in enumerate(split):
        
        
        
        if line.find("Side pot")!=-1: #winner of side pot needs to be "won ($XX.xx)"  not "lost"
            print("Side pot on "+gametime)
        
        
        if state<2:
            state+=1
        elif state==2:
            #print('state is 2')
            if prog3.match(line):
                #print('line matched')
                line=prog3.sub(r'Uncalled bet (\1)',line)
                #print(line)
            elif line=='*** SUMMARY ***':
                state=3
            elif line.find('***')==-1:
                line=line.replace(', and is all in','')
                line=line.replace('posts $','posts big blind $')
                line=prog4.sub(r'posts \1 blind',line)
                line=prog5.sub(r'\1 in chips\2',line)
                line=line.replace('straddles for','posts straddle')
                
                '''if line.find('straddle') and straddleFlag:
                    print("Straddle on "+gametime)
                    straddleFlag=False'''
                
                if line.find(':')==-1 and line.find('Dealt to')==-1:
                    #print('found no : ')
                    #if prog6.search(line):
                        #print(prog6.search(line).group(1))
                    line=prog6.sub(r'\1: ',line)
                    
                if prog7.match(line):
                    tempString=prog7.match(line).group(1)
                    #print(tempString)
                    seatStringStorage.append(tempString) #append seat to storage
                    
                if prog9.match(line):
                    tempString=prog9.match(line).group(1)
                    #print(tempString)
                    if tempString in blindStringStorage:
                        print('double blind post '+tempString+" "+gametime)
                        blindDeletion.append(tempString)
                        
                    else:
                        blindStringStorage.append(tempString)
                    
                    
                    
                
        elif state==3:
            if prog7.match(line):
                line=prog7.sub(r'Seat '+str((int(prog7.match(line).group(1))+1)),line)
                
            if prog7.match(line):
                try:
                    tempString=prog7.match(line).group(1)
                    #print(tempString)
                    seatStringStorage.remove(tempString)
                except:
                    print("possible issue with new player added on gametime "+gametime)
        
        split[i]=line #put lines into the splits
        
        
        
    if len(seatStringStorage)!=0:
        #print("DO X-1! players not removed: "+str(seatStringStorage)+" "+gametime)
        for num in seatStringStorage:
            progNotRemoved=re.compile('^(Seat '+num+': \S+ \(\$\S+ in chips\))') # find the players sitting out
            #progNotRemoved=re.compile('^(Seat '+num+': \S+ \(.*in chips.*)') # find the players sitting out
            for line in list(split):
                if progNotRemoved.search(line):
                    split.remove(line)
    if len(blindDeletion)!=0:
        for string in blindDeletion:
            progDelete=re.compile('^'+string+': posts')
            for line in list(split):
                if progDelete.search(line):
                    split.remove(line)
                    break
        
    #print(blindStringStorage)
            
#print(split_list)


output=open('out\out'+filename,'w')
#output2=open('..\..\Desktop\PS_HH\Nicholas\out'+filename,'w')
for split in split_list:
    for line in split:
        output.write(line+'\n')
output.close()
# Out:
# filename: 062718h
# Monday .2/.5, Table 13:06:16
# Monday .2/.5, Table 13:07:40
# Monday .2/.5, Table 13:07:54
# Monday .2/.5, Table 13:08:49
# Monday .2/.5, Table 13:09:43
# Monday .2/.5, Table 13:10:44
# Monday .2/.5, Table 13:11:53
# Monday .2/.5, Table 13:12:29
# Monday .2/.5, Table 13:13:03
# double blind post O_A 3:13:03
# Monday .2/.5, Table 13:13:50
# Monday .2/.5, Table 13:14:37
# Monday .2/.5, Table 13:15:20
# Monday .2/.5, Table 13:16:14
# Monday .2/.5, Table 13:17:02
# Monday .2/.5, Table 13:17:48
# Monday .2/.5, Table 13:18:07
# Monday .2/.5, Table 13:19:39
# Monday .2/.5, Table 13:19:59
# Monday .2/.5, Table 13:20:12
# Monday .2/.5, Table 13:20:43
# Monday .2/.5, Table 13:20:57
# Monday .2/.5, Table 13:21:11
# Monday .2/.5, Table 13:21:37
# Monday .2/.5, Table 13:22:24
# Monday .2/.5, Table 13:23:04
# Monday .2/.5, Table 13:23:56
# Monday .2/.5, Table 13:24:11
# Monday .2/.5, Table 13:24:37
# Monday .2/.5, Table 13:24:46
# Monday .2/.5, Table 13:26:03
# Monday .2/.5, Table 13:26:29
# Monday .2/.5, Table 13:27:04
# Monday .2/.5, Table 13:27:15
# Monday .2/.5, Table 13:28:19
# Monday .2/.5, Table 13:29:15
# Monday .2/.5, Table 13:29:29
# Monday .2/.5, Table 13:29:42
# Monday .2/.5, Table 13:30:18
# Monday .2/.5, Table 13:30:38
# Monday .2/.5, Table 13:31:02
# Monday .2/.5, Table 13:31:18
# Monday .2/.5, Table 13:32:20
# Monday .2/.5, Table 13:33:09
# Monday .2/.5, Table 13:33:50
# Monday .2/.5, Table 13:34:30
# Monday .2/.5, Table 13:34:51
# Monday .2/.5, Table 13:35:07
# Monday .2/.5, Table 13:35:45
# Monday .2/.5, Table 13:36:02
# Monday .2/.5, Table 13:36:44
# Monday .2/.5, Table 13:37:21
# Monday .2/.5, Table 13:37:48
# Monday .2/.5, Table 13:38:14
# Monday .2/.5, Table 13:38:55
# Monday .2/.5, Table 13:39:28
# Monday .2/.5, Table 13:41:37
# Monday .2/.5, Table 13:43:06
# Monday .2/.5, Table 13:44:13
# Monday .2/.5, Table 13:44:54
# Monday .2/.5, Table 13:45:38
# Monday .2/.5, Table 13:45:56
# Monday .2/.5, Table 13:46:20
# Monday .2/.5, Table 13:47:07
# Monday .2/.5, Table 13:48:06
# Monday .2/.5, Table 13:48:37
# Monday .2/.5, Table 13:49:59
# Monday .2/.5, Table 13:50:48
# Monday .2/.5, Table 13:52:28
# Monday .2/.5, Table 13:52:56
# Monday .2/.5, Table 13:53:28
# Monday .2/.5, Table 13:54:19
# Monday .2/.5, Table 13:54:47
# Monday .2/.5, Table 13:56:17
# Monday .2/.5, Table 13:57:30
# Monday .2/.5, Table 13:57:53
# Monday .2/.5, Table 13:58:53
# Monday .2/.5, Table 13:59:39
# Monday .2/.5, Table 14:00:11
# Monday .2/.5, Table 14:00:31
# Monday .2/.5, Table 14:02:39
# Monday .2/.5, Table 14:03:34
# Monday .2/.5, Table 14:05:09
# Monday .2/.5, Table 14:05:53
# Monday .2/.5, Table 14:06:41
# Monday .2/.5, Table 14:07:50
# Monday .2/.5, Table 14:09:07
# Monday .2/.5, Table 14:09:29
# Monday .2/.5, Table 14:10:51
# Monday .2/.5, Table 14:11:46
# Monday .2/.5, Table 14:12:05
# Monday .2/.5, Table 14:12:50
# Monday .2/.5, Table 14:13:23
# Monday .2/.5, Table 14:14:20
# Monday .2/.5, Table 14:14:44
# Monday .2/.5, Table 14:15:13
# Monday .2/.5, Table 14:15:36
# Monday .2/.5, Table 14:15:51
# Monday .2/.5, Table 14:16:21
# Monday .2/.5, Table 14:17:45
# Monday .2/.5, Table 14:18:32
# Monday .2/.5, Table 14:19:55
# Monday .2/.5, Table 14:20:31
# Monday .2/.5, Table 14:21:13
# Monday .2/.5, Table 14:21:32
# Monday .2/.5, Table 14:23:10
# Monday .2/.5, Table 14:24:41
# Monday .2/.5, Table 14:26:24
# Monday .2/.5, Table 14:27:09
# Monday .2/.5, Table 14:28:08
# Monday .2/.5, Table 14:28:36
# Monday .2/.5, Table 14:29:16
# Monday .2/.5, Table 14:30:08
# Monday .2/.5, Table 14:31:12
# Monday .2/.5, Table 14:31:51
# Monday .2/.5, Table 14:32:38
# Monday .2/.5, Table 14:33:12
# Monday .2/.5, Table 14:34:31
# Monday .2/.5, Table 14:36:10
# Monday .2/.5, Table 14:36:55
# Monday .2/.5, Table 14:38:25
# Monday .2/.5, Table 14:38:41
# Monday .2/.5, Table 14:39:59
# Monday .2/.5, Table 14:41:06
# Monday .2/.5, Table 14:42:16
# Monday .2/.5, Table 14:43:39
# Monday .2/.5, Table 14:44:10
# Monday .2/.5, Table 14:44:45
# Monday .2/.5, Table 14:45:44
# Monday .2/.5, Table 14:46:24
# Monday .2/.5, Table 14:47:53
# Monday .2/.5, Table 14:48:46
# Monday .2/.5, Table 14:49:09
# Monday .2/.5, Table 14:50:01
# Monday .2/.5, Table 14:50:38
# Monday .2/.5, Table 14:51:17
# Monday .2/.5, Table 14:52:15
# Monday .2/.5, Table 14:53:06
# Monday .2/.5, Table 14:53:29
# Monday .2/.5, Table 14:54:34
# Monday .2/.5, Table 14:56:44
# Monday .2/.5, Table 14:58:07
# Monday .2/.5, Table 14:59:36
# Monday .2/.5, Table 15:01:09
# Monday .2/.5, Table 15:01:41
# Monday .2/.5, Table 15:02:53
# Monday .2/.5, Table 15:03:25
# Monday .2/.5, Table 15:03:54
# Monday .2/.5, Table 15:04:46
# Monday .2/.5, Table 15:06:22
# Monday .2/.5, Table 15:08:26
# Monday .2/.5, Table 15:10:32
# Monday .2/.5, Table 15:11:27
# Monday .2/.5, Table 15:12:23
# Monday .2/.5, Table 15:13:02
# Monday .2/.5, Table 15:14:13
# Monday .2/.5, Table 15:16:22
# Monday .2/.5, Table 15:17:09
# Monday .2/.5, Table 15:18:49
# Monday .2/.5, Table 15:19:34
# Monday .2/.5, Table 15:20:21
# Monday .2/.5, Table 15:21:52
# Monday .2/.5, Table 15:22:20
# Monday .2/.5, Table 15:24:27
# Monday .2/.5, Table 15:25:27
# Monday .2/.5, Table 15:27:36
# Monday .2/.5, Table 15:28:19
# Monday .2/.5, Table 15:29:40
# Monday .2/.5, Table 15:30:32
# Monday .2/.5, Table 15:31:18
# Monday .2/.5, Table 15:31:51
# Monday .2/.5, Table 15:32:54
# Monday .2/.5, Table 15:33:27
# Monday .2/.5, Table 15:33:56
# Monday .2/.5, Table 15:34:30
# Monday .2/.5, Table 15:34:51
# Monday .2/.5, Table 15:36:18
# Side pot on 5:36:18
# Monday .2/.5, Table 15:38:02
# Monday .2/.5, Table 15:38:24
# Monday .2/.5, Table 15:38:51
# Monday .2/.5, Table 15:39:57
# Monday .2/.5, Table 15:40:50
# Monday .2/.5, Table 15:41:28
# Monday .2/.5, Table 15:42:44
# Monday .2/.5, Table 15:43:23
# Monday .2/.5, Table 15:44:03
# Monday .2/.5, Table 15:45:05
# Monday .2/.5, Table 15:45:59
# Monday .2/.5, Table 15:47:13
# Monday .2/.5, Table 15:47:50
# Monday .2/.5, Table 15:48:26
# Monday .2/.5, Table 15:49:15
# Monday .2/.5, Table 15:49:57
# Monday .2/.5, Table 15:50:46
# Monday .2/.5, Table 15:51:48
# Monday .2/.5, Table 15:52:00
# Monday .2/.5, Table 15:53:19
# Monday .2/.5, Table 15:54:03
# Monday .2/.5, Table 15:54:41
# Monday .2/.5, Table 15:55:38
# Monday .2/.5, Table 15:57:00
# Monday .2/.5, Table 15:57:21
# Monday .2/.5, Table 15:58:16
# Monday .2/.5, Table 16:00:00
# Monday .2/.5, Table 16:00:23
# Monday .2/.5, Table 16:01:21
# Monday .2/.5, Table 16:02:10
# Monday .2/.5, Table 16:02:49
# Monday .2/.5, Table 16:03:04
# Monday .2/.5, Table 16:03:51
# Monday .2/.5, Table 16:04:50
# Monday .2/.5, Table 16:05:27
# Monday .2/.5, Table 16:06:07
# Monday .2/.5, Table 16:06:59
# Monday .2/.5, Table 16:07:41
# Monday .2/.5, Table 16:08:20
# Monday .2/.5, Table 16:09:20
# Monday .2/.5, Table 16:09:50
# Monday .2/.5, Table 16:10:46
# Monday .2/.5, Table 16:11:24
# Monday .2/.5, Table 16:11:55
# Monday .2/.5, Table 16:12:46
# Monday .2/.5, Table 16:13:23
# Monday .2/.5, Table 16:14:09
# Monday .2/.5, Table 16:14:57
# Monday .2/.5, Table 16:15:48
# Monday .2/.5, Table 16:16:24
# Monday .2/.5, Table 16:17:19
# Monday .2/.5, Table 16:18:04
# Monday .2/.5, Table 16:19:04
# Monday .2/.5, Table 16:19:27
# Monday .2/.5, Table 16:20:17
# Monday .2/.5, Table 16:20:59
# Monday .2/.5, Table 16:21:44
# Monday .2/.5, Table 16:22:20
# Monday .2/.5, Table 16:22:44
# Monday .2/.5, Table 16:22:57
# Monday .2/.5, Table 16:23:31
# Monday .2/.5, Table 16:24:09
# Monday .2/.5, Table 16:24:56
# Monday .2/.5, Table 16:25:51
# Monday .2/.5, Table 16:26:11
# Monday .2/.5, Table 16:26:20
# Monday .2/.5, Table 16:26:35
# Monday .2/.5, Table 16:27:07
# Monday .2/.5, Table 16:27:15
# Monday .2/.5, Table 16:27:42
# Monday .2/.5, Table 16:28:18
# Monday .2/.5, Table 16:28:40
# Monday .2/.5, Table 16:28:48
# Monday .2/.5, Table 16:29:02
# Monday .2/.5, Table 16:29:10
# Monday .2/.5, Table 16:29:38
# Monday .2/.5, Table 16:29:58
# Monday .2/.5, Table 16:30:47
# Monday .2/.5, Table 16:31:23
# Monday .2/.5, Table 16:32:07
# Monday .2/.5, Table 16:32:32
# Monday .2/.5, Table 16:33:15
# Monday .2/.5, Table 16:34:13
# Monday .2/.5, Table 16:34:51
# Monday .2/.5, Table 16:35:02
# Monday .2/.5, Table 16:35:41
# Monday .2/.5, Table 16:36:22
# Monday .2/.5, Table 16:36:32
# Monday .2/.5, Table 16:36:55
# Monday .2/.5, Table 16:37:35
# Monday .2/.5, Table 16:38:11
# Monday .2/.5, Table 16:38:26
# Monday .2/.5, Table 16:39:20
# Monday .2/.5, Table 16:40:07
# Monday .2/.5, Table 16:40:32
# Monday .2/.5, Table 16:41:21
# Monday .2/.5, Table 16:42:04
# Monday .2/.5, Table 16:42:52
# Monday .2/.5, Table 16:43:33
# Monday .2/.5, Table 16:43:44
# Monday .2/.5, Table 16:44:38
# Monday .2/.5, Table 16:45:19
# Monday .2/.5, Table 16:45:52
# Monday .2/.5, Table 16:46:42
# Monday .2/.5, Table 16:47:06
# Monday .2/.5, Table 16:47:34
# Monday .2/.5, Table 16:48:33
# Monday .2/.5, Table 16:48:51
# Monday .2/.5, Table 16:49:31
# Monday .2/.5, Table 16:49:55
# Monday .2/.5, Table 16:50:19
# Monday .2/.5, Table 16:51:02
# Monday .2/.5, Table 16:51:29
# Monday .2/.5, Table 16:51:51
# Monday .2/.5, Table 16:52:16
# Monday .2/.5, Table 16:53:14
# Monday .2/.5, Table 16:53:43
# Monday .2/.5, Table 16:54:22
# Monday .2/.5, Table 16:54:58
# Monday .2/.5, Table 16:55:58
# Monday .2/.5, Table 16:56:53
# Monday .2/.5, Table 16:57:29
# Monday .2/.5, Table 16:57:53
# Monday .2/.5, Table 16:58:54
# Monday .2/.5, Table 16:59:13
# Monday .2/.5, Table 16:59:48
# Monday .2/.5, Table 17:00:25
# Monday .2/.5, Table 17:00:56
# Monday .2/.5, Table 17:01:34
# Monday .2/.5, Table 17:02:08
# Monday .2/.5, Table 17:02:50
# Monday .2/.5, Table 17:03:21
# Monday .2/.5, Table 17:04:07
# Monday .2/.5, Table 17:04:45
# Monday .2/.5, Table 17:05:25
# Monday .2/.5, Table 17:06:06
# Monday .2/.5, Table 17:06:49
# Monday .2/.5, Table 17:07:31
# Monday .2/.5, Table 17:07:56
# Monday .2/.5, Table 17:08:24
# Monday .2/.5, Table 17:08:35
# Monday .2/.5, Table 17:08:57
# Monday .2/.5, Table 17:09:17
# Monday .2/.5, Table 17:09:38
# Monday .2/.5, Table 17:09:52
# Monday .2/.5, Table 17:10:15
# Monday .2/.5, Table 17:11:19
# Monday .2/.5, Table 17:11:59
# Monday .2/.5, Table 17:12:16
# Monday .2/.5, Table 17:12:59
# Monday .2/.5, Table 17:13:40
# Monday .2/.5, Table 17:14:19
# Monday .2/.5, Table 17:14:35
# Monday .2/.5, Table 17:15:07
# Monday .2/.5, Table 17:15:21
# Monday .2/.5, Table 17:15:41
# Monday .2/.5, Table 17:15:57
# Monday .2/.5, Table 17:16:28
# Monday .2/.5, Table 17:17:03
# Monday .2/.5, Table 17:17:26
# Monday .2/.5, Table 17:17:38
# Monday .2/.5, Table 17:18:24
# Monday .2/.5, Table 17:18:49
# Monday .2/.5, Table 17:18:58
# Monday .2/.5, Table 17:19:39
# Monday .2/.5, Table 17:19:50
# Monday .2/.5, Table 17:20:09
# Monday .2/.5, Table 17:20:19
# Monday .2/.5, Table 17:20:52
# Monday .2/.5, Table 17:21:17
# Monday .2/.5, Table 17:22:03
# Monday .2/.5, Table 17:22:27
# Monday .2/.5, Table 17:23:00
# Monday .2/.5, Table 17:23:31
# Monday .2/.5, Table 17:24:03
# Monday .2/.5, Table 17:24:37
# Monday .2/.5, Table 17:25:03
# Monday .2/.5, Table 17:25:25
# Monday .2/.5, Table 17:25:47
# Monday .2/.5, Table 17:25:59
# Monday .2/.5, Table 17:26:22
# Monday .2/.5, Table 17:26:58
# Monday .2/.5, Table 17:27:21
# Monday .2/.5, Table 17:27:46
# Monday .2/.5, Table 17:27:56
# Monday .2/.5, Table 17:28:45
# Monday .2/.5, Table 17:29:11
# Monday .2/.5, Table 17:29:48
# Monday .2/.5, Table 17:30:07
# Monday .2/.5, Table 17:30:44
# Monday .2/.5, Table 17:31:34
# Monday .2/.5, Table 17:32:20
# Monday .2/.5, Table 17:32:41
# Monday .2/.5, Table 17:33:54
# Monday .2/.5, Table 17:34:03
# Monday .2/.5, Table 17:35:14
# Monday .2/.5, Table 17:35:34
# Monday .2/.5, Table 17:35:42
# Monday .2/.5, Table 17:36:11
# Monday .2/.5, Table 17:36:19
# Monday .2/.5, Table 17:36:54
# Monday .2/.5, Table 17:37:30
# Monday .2/.5, Table 17:37:59
# Monday .2/.5, Table 17:38:18
# Monday .2/.5, Table 17:38:41
# Monday .2/.5, Table 17:39:15
# Monday .2/.5, Table 17:39:46
# Monday .2/.5, Table 17:40:05
# Monday .2/.5, Table 17:40:13
# Monday .2/.5, Table 17:40:37
# Monday .2/.5, Table 17:41:05
# Monday .2/.5, Table 17:41:57
# Monday .2/.5, Table 17:42:15
# Monday .2/.5, Table 17:42:34
# Monday .2/.5, Table 17:42:42
# Monday .2/.5, Table 17:43:12
# Monday .2/.5, Table 17:43:28
# Monday .2/.5, Table 17:44:08
# Monday .2/.5, Table 17:44:49
# Monday .2/.5, Table 17:45:01
# Monday .2/.5, Table 17:45:25
# Monday .2/.5, Table 17:45:34
# Monday .2/.5, Table 17:45:51
# Monday .2/.5, Table 17:46:32
# Monday .2/.5, Table 17:46:41
# Monday .2/.5, Table 17:46:49
# Monday .2/.5, Table 17:47:22
# Monday .2/.5, Table 17:47:33
# Monday .2/.5, Table 17:48:00
# Monday .2/.5, Table 17:48:48
# Monday .2/.5, Table 17:49:53
# Monday .2/.5, Table 17:50:05
# Monday .2/.5, Table 17:50:33
# Monday .2/.5, Table 17:51:33
# Monday .2/.5, Table 17:52:17
# Monday .2/.5, Table 17:52:51
# Monday .2/.5, Table 17:53:08
# Monday .2/.5, Table 17:53:43
# Monday .2/.5, Table 17:54:29
# Monday .2/.5, Table 17:54:58
# Monday .2/.5, Table 17:55:21
# Monday .2/.5, Table 17:55:43
# Monday .2/.5, Table 17:56:28
# Monday .2/.5, Table 17:56:36
# Monday .2/.5, Table 17:56:56
# Monday .2/.5, Table 17:57:04
# Monday .2/.5, Table 17:57:46
# Monday .2/.5, Table 17:58:39
# Monday .2/.5, Table 17:59:12
# Monday .2/.5, Table 17:59:31
# Monday .2/.5, Table 18:00:30
# Monday .2/.5, Table 18:01:06
# Monday .2/.5, Table 18:02:07
# Monday .2/.5, Table 18:02:16
# Monday .2/.5, Table 18:02:48
# Monday .2/.5, Table 18:03:04
# Monday .2/.5, Table 18:03:25
# Monday .2/.5, Table 18:03:34
# Monday .2/.5, Table 18:03:59
# Monday .2/.5, Table 18:04:08
# Monday .2/.5, Table 18:04:45
# Monday .2/.5, Table 18:05:37
# Monday .2/.5, Table 18:06:12
# Monday .2/.5, Table 18:06:31
# Monday .2/.5, Table 18:06:48
# Monday .2/.5, Table 18:06:57
# Monday .2/.5, Table 18:07:13
# Monday .2/.5, Table 18:07:22
# Monday .2/.5, Table 18:07:39
# Monday .2/.5, Table 18:07:59
# Monday .2/.5, Table 18:08:17
# Monday .2/.5, Table 18:08:50
# Monday .2/.5, Table 18:09:10
# Monday .2/.5, Table 18:09:38
# Monday .2/.5, Table 18:10:26
# Monday .2/.5, Table 18:11:22
# Monday .2/.5, Table 18:11:41
# Monday .2/.5, Table 18:12:12
# Monday .2/.5, Table 18:12:40
# Monday .2/.5, Table 18:12:48
# Monday .2/.5, Table 18:13:06
# Monday .2/.5, Table 18:13:33
# Monday .2/.5, Table 18:14:10
# Monday .2/.5, Table 18:14:25
# Monday .2/.5, Table 18:14:46
# Monday .2/.5, Table 18:14:56
# Monday .2/.5, Table 18:15:21
# Monday .2/.5, Table 18:15:30
# Monday .2/.5, Table 18:16:04
# Monday .2/.5, Table 18:16:13
# Monday .2/.5, Table 18:16:21
# Monday .2/.5, Table 18:16:30
# Monday .2/.5, Table 18:16:42
# Monday .2/.5, Table 18:16:51
# Monday .2/.5, Table 18:17:09
# Monday .2/.5, Table 18:18:11
# Monday .2/.5, Table 18:18:50
# Monday .2/.5, Table 18:19:01
# Monday .2/.5, Table 18:19:30
# Monday .2/.5, Table 18:19:40
# Monday .2/.5, Table 18:19:49
# Monday .2/.5, Table 18:20:11
# Monday .2/.5, Table 18:20:21
# Monday .2/.5, Table 18:20:29
# Monday .2/.5, Table 18:21:01
# Monday .2/.5, Table 18:21:10
# Monday .2/.5, Table 18:21:31
# Monday .2/.5, Table 18:22:04
# Monday .2/.5, Table 18:22:35
# Monday .2/.5, Table 18:22:54
# Monday .2/.5, Table 18:23:32
# Monday .2/.5, Table 18:23:55
# Monday .2/.5, Table 18:24:21
# Monday .2/.5, Table 18:24:34
# Monday .2/.5, Table 18:24:43
# Monday .2/.5, Table 18:25:24
# Monday .2/.5, Table 18:25:54
# Monday .2/.5, Table 18:26:02
# Monday .2/.5, Table 18:26:20
# Monday .2/.5, Table 18:27:12
# Monday .2/.5, Table 18:28:02
# Monday .2/.5, Table 18:28:11
# Monday .2/.5, Table 18:28:45
# Monday .2/.5, Table 18:28:56
# Monday .2/.5, Table 18:29:36
# Monday .2/.5, Table 18:30:08
# Monday .2/.5, Table 18:30:42
# Monday .2/.5, Table 18:31:17
# Monday .2/.5, Table 18:31:47
# Monday .2/.5, Table 18:31:55
# Monday .2/.5, Table 18:32:34
# Monday .2/.5, Table 18:32:42
# Monday .2/.5, Table 18:33:18
# Monday .2/.5, Table 18:33:44
# Monday .2/.5, Table 18:34:01
# Monday .2/.5, Table 18:34:09
# Monday .2/.5, Table 18:34:32
# Monday .2/.5, Table 18:35:12
# Monday .2/.5, Table 18:35:57
# Monday .2/.5, Table 18:36:32
# Monday .2/.5, Table 18:36:55
# Monday .2/.5, Table 18:37:29
# Monday .2/.5, Table 18:37:56
# Monday .2/.5, Table 18:38:05
# Monday .2/.5, Table 18:38:32
# Monday .2/.5, Table 18:38:41
# Monday .2/.5, Table 18:39:13
# Monday .2/.5, Table 18:39:21
# Monday .2/.5, Table 18:39:43
# Monday .2/.5, Table 18:40:21
# Monday .2/.5, Table 18:41:00
# Monday .2/.5, Table 18:41:09
# Monday .2/.5, Table 18:41:40
# Monday .2/.5, Table 18:41:49
# Monday .2/.5, Table 18:42:10
# Monday .2/.5, Table 18:42:44
# Monday .2/.5, Table 18:43:17
# Monday .2/.5, Table 18:43:40
# Monday .2/.5, Table 18:44:04
# Monday .2/.5, Table 18:44:17
# Monday .2/.5, Table 18:44:35
# Monday .2/.5, Table 18:44:43
# Monday .2/.5, Table 18:45:01
# Monday .2/.5, Table 18:45:11
# Monday .2/.5, Table 18:45:37
# Monday .2/.5, Table 18:45:46
# Monday .2/.5, Table 18:46:21
# Monday .2/.5, Table 18:46:30
# Monday .2/.5, Table 18:46:49
# Monday .2/.5, Table 18:47:24
# Monday .2/.5, Table 18:48:05
# Monday .2/.5, Table 18:48:13
# Monday .2/.5, Table 18:48:37
# Monday .2/.5, Table 18:49:01
# Monday .2/.5, Table 18:49:16
# Monday .2/.5, Table 18:49:48
# Monday .2/.5, Table 18:50:29
# Monday .2/.5, Table 18:50:41
# Monday .2/.5, Table 18:51:17
# Monday .2/.5, Table 18:51:25
# Monday .2/.5, Table 18:52:00
# Monday .2/.5, Table 18:52:19
# Monday .2/.5, Table 18:52:47
# Monday .2/.5, Table 18:52:56
# Monday .2/.5, Table 18:53:40
# Monday .2/.5, Table 18:53:48
# Monday .2/.5, Table 18:53:59
# Monday .2/.5, Table 18:54:32
# Monday .2/.5, Table 18:54:58
# Monday .2/.5, Table 18:55:09
# Monday .2/.5, Table 18:55:37
# Monday .2/.5, Table 18:55:57
# Monday .2/.5, Table 18:56:15
# Monday .2/.5, Table 18:56:27
# Monday .2/.5, Table 18:57:24
# Monday .2/.5, Table 18:57:50
# Monday .2/.5, Table 18:58:21
# Monday .2/.5, Table 18:58:53
# Monday .2/.5, Table 18:59:17
# Monday .2/.5, Table 18:59:56
# Monday .2/.5, Table 19:00:29
# Monday .2/.5, Table 19:01:17
# Monday .2/.5, Table 19:01:39
# Monday .2/.5, Table 19:01:49
# Monday .2/.5, Table 19:02:08
# Monday .2/.5, Table 19:02:16
# Monday .2/.5, Table 19:02:24
# Monday .2/.5, Table 19:02:35
# Monday .2/.5, Table 19:02:55

# %% [markdown]
# ##
